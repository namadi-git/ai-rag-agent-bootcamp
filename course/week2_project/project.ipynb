# %%
from openai import OpenAI
from pydantic import BaseModel
import json
import numpy as np
from tqdm import tqdm
from dotenv import load_dotenv
from typing import Any, Dict, List, TypedDict
load_dotenv()

openai_client = OpenAI()

# %% [markdown]
# ## Fetch Web Page Tool

# %%
import requests
import json

# %%
# Jina Reader API Base
JINA_READER_BASE = "https://r.jina.ai/"

# %%
TARGET_URL = "https://en.wikipedia.org/wiki/Rose"  # Target URL to scrape

# %%
markdown_url = JINA_READER_BASE + TARGET_URL

# %%
markdown_url
# Out:
# 'https://r.jina.ai/https://en.wikipedia.org/wiki/Rose'

# %%
try:
    response = requests.get(markdown_url)
    response.raise_for_status() # Raises an exception for 4xx or 5xx status codes
    
    clean_markdown = response.text
    print("--- Clean Content (Markdown) ---")
    print(clean_markdown[:500] + "...") # Print the first 500 characters
    
except requests.exceptions.RequestException as e:
    print(f"Error fetching page: {e}")
# Out:
# --- Clean Content (Markdown) ---
# Title: Rose
#
# URL Source: https://en.wikipedia.org/wiki/Rose
#
# Published Time: 2002-02-01T12:22:29Z
#
# Markdown Content:
# | Rose Temporal range: Eocene–Recent [PreꞒ](https://en.wikipedia.org/wiki/Precambrian "Precambrian") [Ꞓ](https://en.wikipedia.org/wiki/Cambrian "Cambrian") [O](https://en.wikipedia.org/wiki/Ordovician "Ordovician") [S](https://en.wikipedia.org/wiki/Silurian "Silurian") [D](https://en.wikipedia.org/wiki/Devonian "Devonian") [C](https://en.wikipedia.org/wiki/Carboniferous "Carbonife...

# %%
print(clean_markdown)
# Out:
# Title: Rose
#
# URL Source: https://en.wikipedia.org/wiki/Rose
#
# Published Time: 2002-02-01T12:22:29Z
#
# Markdown Content:
# | Rose Temporal range: Eocene–Recent [PreꞒ](https://en.wikipedia.org/wiki/Precambrian "Precambrian") [Ꞓ](https://en.wikipedia.org/wiki/Cambrian "Cambrian") [O](https://en.wikipedia.org/wiki/Ordovician "Ordovician") [S](https://en.wikipedia.org/wiki/Silurian "Silurian") [D](https://en.wikipedia.org/wiki/Devonian "Devonian") [C](https://en.wikipedia.org/wiki/Carboniferous "Carboniferous") [P](https://en.wikipedia.org/wiki/Permian "Permian") [T](https://en.wikipedia.org/wiki/Triassic "Triassic") [J](https://en.wikipedia.org/wiki/Jurassic "Jurassic") [K](https://en.wikipedia.org/wiki/Cretaceous "Cretaceous") [Pg](https://en.wikipedia.org/wiki/Paleogene "Paleogene") [N](https://en.wikipedia.org/wiki/Neogene "Neogene") |
# | --- |
# | [![Image 1](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Rosa_rubiginosa_1.jpg/250px-Rosa_rubiginosa_1.jpg)](https://en.wikipedia.org/wiki/File:Rosa_rubiginosa_1.jpg) |
# | _[Rosa rubiginosa](https://en.wikipedia.org/wiki/Rosa\_rubiginosa "Rosa rubiginosa")_, a wild rose native to [Europe](https://en.wikipedia.org/wiki/Europe "Europe") and [West Asia](https://en.wikipedia.org/wiki/West_Asia "West Asia") |
# | [![Image 2](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/
#
# A **rose** is either a woody [perennial](https://en.wikipedia.org/wiki/Perennial_plant "Perennial plant")[flowering plant](https://en.wikipedia.org/wiki/Flowering_plant "Flowering plant") of the [genus](https://en.wikipedia.org/wiki/Genus "Genus")_**Rosa**_ (),[[4]](https://en.wikipedia.org/wiki/Rose#cite_note-W3-4) in the family [Rosaceae](https://en.wikipedia.org/wiki/Rosaceae "Rosaceae") (),[[4]](https://en.wikipedia.org/wiki/Rose#cite_note-W3-4) or the [flower](https://en.wikipedia.org/wiki/Flower "Flower") it bears. There are over three hundred [species](https://en.wikipedia.org/wiki/Rose_species "Rose species") and [tens of thousands](https://en.wikipedia.org/wiki/Garden_roses "Garden roses") of [cultivars](https://en.wikipedia.org/wiki/Cultivar "Cultivar").[[5]](https://en.wikipedia.org/wiki/Rose#cite_note-5) They form a group of [plants](https://en.wikipedia.org/wiki/Plant "Plant") that can be erect [shrubs](https://en.wikipedia.org/wiki/Shrub "Shrub"), climbing, or trailing, with stems that are often armed with sharp [prickles](https://en.wikipedia.org/wiki/Thorns,_spines,_and_prickles "Thorns, spines, and prickles").[[6]](https://en.wikipedia.org/wiki/Rose#cite_note-Britannica-6) Their flowers vary in size and shape and are usually large and showy, in colours ranging from white through pinks, reds, oranges and yellows. Most species are native to [Asia](https://en.wikipedia.org/wiki/Asia "Asia"), with smaller numbers native to [Europe](https://en.wikipedia.org/wiki/Europe "Europe"), [North America](https://en.wikipedia.org/wiki/North_America "North America"), and [Northwest Africa](https://en.wikipedia.org/wiki/Northwest_Africa "Northwest Africa").[[6]](https://en.wikipedia.org/wiki/Rose#cite_note-Britannica-6) Species, [cultivars](https://en.wikipedia.org/wiki/Cultivar "Cultivar") and [hybrids](https://en.wikipedia.org/wiki/Hybrid_(biology) "Hybrid (biology)") are all widely grown for their beauty and often are fragrant. Roses have acquired cultural significance in many societies. Rose plants range in size from compact, miniature roses to climbers that can reach seven meters in height.[[6]](https://en.wikipedia.org/wiki/Rose#cite_note-Britannica-6) Different species hybridize easily, and this has been used in the development of the wide range of [garden roses](https://en.wikipedia.org/wiki/Garden_roses "Garden roses").
#
# Etymology
# ---------
#
# The name _rose_ comes from Latin _rosa_, which was perhaps borrowed from [Oscan](https://en.wikipedia.org/wiki/Oscan "Oscan"), from [Greek](https://en.wikipedia.org/wiki/Greek_language "Greek language") ῥόδον _rhódon_ ([Aeolic](https://en.wikipedia.org/wiki/Aeolic_Greek "Aeolic Greek") βρόδον _wródon_), itself borrowed from [Old Persian](https://en.wikipedia.org/wiki/Old_Persian_language "Old Persian language")_wrd-_ (_wurdi_), related to [Avestan](https://en.wikipedia.org/wiki/Avestan_language "Avestan language")_varəδa_, [Sogdian](https://en.wikipedia.org/wiki/Sogdian_language "Sogdian language")_ward_, [Parthian](https://en.wikipedia.org/wiki/Parthian_language "Parthian language")_wâr_.[[7]](https://en.wikipedia.org/wiki/Rose#cite_note-7)[[8]](https://en.wikipedia.org/wiki/Rose#cite_note-8)
#
# Botany
# ------
#
# The [leaves](https://en.wikipedia.org/wiki/Leaves "Leaves") are borne alternately on the stem. In most species, they are 5 to 15 centimetres (2.0 to 5.9 in) long, [pinnate](https://en.wikipedia.org/wiki/Pinnate "Pinnate"), with (3–) 5–9 (−13) leaflets and basal [stipules](https://en.wikipedia.org/wiki/Stipule "Stipule"); the leaflets usually have a serrated margin, and often a few small prickles on the underside of the stem. Most roses are [deciduous](https://en.wikipedia.org/wiki/Deciduous "Deciduous") but a few (particularly from [Southeast Asia](https://en.wikipedia.org/wiki/Southeast_Asia "Southeast Asia")) are [evergreen](https://en.wikipedia.org/wiki/Evergreen "Evergreen") or nearly so.
#
# ### Thorns
#
# The sharp growths along a rose stem, though commonly called "thorns", are technically [prickles](https://en.wikipedia.org/wiki/Thorns,_spines_and_prickles "Thorns, spines and prickles"), outgrowths of the [epidermis](https://en.wikipedia.org/wiki/Epidermis_(botany) "Epidermis (botany)") (the outer layer of tissue of the stem), unlike true thorns, which are [modified stems](https://en.wikipedia.org/wiki/Aerial_stem_modification "Aerial stem modification"). Rose prickles are typically sickle-shaped hooks, which aid the rose in hanging onto other vegetation when growing over it. Some species such as _[Rosa rugosa](https://en.wikipedia.org/wiki/Rosa\_rugosa "Rosa rugosa")_ and _[R.pimpinellifolia](https://en.wikipedia.org/wiki/Rosa\_pimpinellifolia "Rosa pimpinellifolia")_ have densely packed straight prickles, probably an adaptation to reduce [browsing](https://en.wikipedia.org/wiki/Browsing_(herbivory) "Browsing (herbivory)") by animals, but also possibly an adaptation to trap wind-blown [sand](https://en.wikipedia.org/wiki/Sand "Sand") and so reduce [erosion](https://en.wikipedia.org/wiki/Erosion "Erosion") and protect their [roots](https://en.wikipedia.org/wiki/Root "Root") (both of these species grow naturally on [coastal](https://en.wikipedia.org/wiki/Coast "Coast")[sand dunes](https://en.wikipedia.org/wiki/Dune "Dune")). Despite the presence of prickles, roses are frequently browsed by [deer](https://en.wikipedia.org/wiki/Deer "Deer"). A few species of roses have only vestigial prickles that have no points.[_[citation needed](https://en.wikipedia.org/wiki/Wikipedia:Citation\_needed "Wikipedia:Citation needed")_]
#
# Plant geneticist Zachary Lippman of [Cold Spring Harbor Laboratory](https://en.wikipedia.org/wiki/Cold_Spring_Harbor_Laboratory "Cold Spring Harbor Laboratory") found that prickles are controlled by the LOG gene.[[9]](https://en.wikipedia.org/wiki/Rose#cite_note-9)[[10]](https://en.wikipedia.org/wiki/Rose#cite_note-10) Blocking the LOG gene in roses reduced the thorns (large prickles) into tiny buds.
#
# *   [![Image 4: Rose thorns](https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Rose_Prickles.jpg/250px-Rose_Prickles.jpg)](https://en.wikipedia.org/wiki/File:Rose_Prickles.jpg "Rose thorns")
#
# Rose thorns
#
# *   [![Image 5: Rose leaflets](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Roseleaves3800px.JPG/500px-Roseleaves3800px.JPG)](https://en.wikipedia.org/wiki/File:Roseleaves3800px.JPG "Rose leaflets")
#
# Rose leaflets
#
# ### Flower
#
# The [flowers](https://en.wikipedia.org/wiki/Flower "Flower") of most species have five petals, with the exception of _[Rosa omeiensis](https://en.wikipedia.org/wiki/Rosa\_omeiensis "Rosa omeiensis")_ and _[Rosa sericea](https://en.wikipedia.org/wiki/Rosa\_sericea "Rosa sericea")_, which usually have only four. Each [petal](https://en.wikipedia.org/wiki/Petal "Petal") is divided into two distinct lobes and is usually white or pink, though in a few species yellow or red. Beneath the petals are five [sepals](https://en.wikipedia.org/wiki/Sepals "Sepals") (or in the case of some _Rosa omeiensis_ and _Rosa sericea_, four). These may be long enough to be visible when viewed from above and appear as green points alternating with the rounded petals. The coloured petals are fused on the axis and arranged in five bundles forming a circle, the petal bundles expand further from each other;[[11]](https://en.wikipedia.org/wiki/Rose#cite_note-AJB-11): 458–459  the petals form a cup or disc surrounding the [gynoecium](https://en.wikipedia.org/wiki/Gynoecium "Gynoecium").[[11]](https://en.wikipedia.org/wiki/Rose#cite_note-AJB-11): 453  There are multiple [superior](https://en.wikipedia.org/wiki/Ovary_(plants)#Superior_ovary "Ovary (plants)") ovaries that develop into [achenes](https://en.wikipedia.org/wiki/Achene "Achene").[[12]](https://en.wikipedia.org/wiki/Rose#cite_note-12)
#
# *   [![Image 6: Longitudinal section of a developing rose hip](https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Rose_hip_02_ies.jpg/330px-Rose_hip_02_ies.jpg)](https://en.wikipedia.org/wiki/File:Rose_hip_02_ies.jpg "Longitudinal section of a developing rose hip")
#
# Longitudinal section of a developing rose hip
#
# *   [![Image 7: Exterior view of rose buds](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Roses_Boutons_FR_2012.jpg/330px-Roses_Boutons_FR_2012.jpg)](https://en.wikipedia.org/wiki/File:Roses_Boutons_FR_2012.jpg "Exterior view of rose buds")
#
# Exterior view of rose buds
#
# *   [![Image 8: A close-up of a climbing rose](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/A_close-up_of_climbing_roses.jpg/500px-A_close-up_of_climbing_roses.jpg)](https://en.wikipedia.org/wiki/File:A_close-up_of_climbing_roses.jpg "A close-up of a climbing rose")
#
# A close-up of a climbing rose
#
# ### Reproduction
#
# Roses are insect-pollinated in nature. A fertilized ovary forms a berry-like [aggregate fruit](https://en.wikipedia.org/wiki/Aggregate_fruit "Aggregate fruit") called a "[hip](https://en.wikipedia.org/wiki/Rose_hip "Rose hip")". The hips of most species are red, but a few (e.g. _[Rosa pimpinellifolia](https://en.wikipedia.org/wiki/Rosa\_pimpinellifolia "Rosa pimpinellifolia")_) have dark purple to black hips. Each hip comprises an outer fleshy layer, the [hypanthium](https://en.wikipedia.org/wiki/Hypanthium "Hypanthium"), which contains 5–160 "seeds" (technically dry single-seeded fruits called [achenes](https://en.wikipedia.org/wiki/Achene "Achene")) embedded in a matrix of fine, but stiff, hairs. Rose hips of some species, especially the [dog rose](https://en.wikipedia.org/wiki/Dog_rose "Dog rose") (_Rosa canina_) and [rugosa rose](https://en.wikipedia.org/wiki/Rugosa_rose "Rugosa rose") (_R.rugosa_), are very rich in [vitamin C](https://en.wikipedia.org/wiki/Vitamin_C "Vitamin C"), among the richest sources of any plant. The hips are eaten by fruit-eating [birds](https://en.wikipedia.org/wiki/Bird "Bird") such as [thrushes](https://en.wikipedia.org/wiki/Thrush_(bird) "Thrush (bird)") and [waxwings](https://en.wikipedia.org/wiki/Waxwing "Waxwing"), which then disperse the [seeds](https://en.wikipedia.org/wiki/Seed "Seed") in their droppings.
#
# Many of the domestic [cultivars](https://en.wikipedia.org/wiki/Cultivar "Cultivar") do not produce hips, as the [flowers](https://en.wikipedia.org/wiki/Flower "Flower") are too tightly petalled to provide access for [pollination](https://en.wikipedia.org/wiki/Pollination "Pollination") and the plants can only propagate through human-made [cuttings](https://en.wikipedia.org/wiki/Cutting_(plant) "Cutting (plant)").[_[verification needed](https://en.wikipedia.org/wiki/Wikipedia:Verifiability "Wikipedia:Verifiability")_]
#
# ### Evolution
#
# The oldest remains of roses are from the Late [Eocene](https://en.wikipedia.org/wiki/Eocene "Eocene")[Florissant Formation](https://en.wikipedia.org/wiki/Florissant_Formation "Florissant Formation") of Colorado.[[13]](https://en.wikipedia.org/wiki/Rose#cite_note-13) Roses were present in [Europe](https://en.wikipedia.org/wiki/Europe "Europe") by the early [Oligocene](https://en.wikipedia.org/wiki/Oligocene "Oligocene").[[14]](https://en.wikipedia.org/wiki/Rose#cite_note-14)
#
# Today's garden roses come from 18th-century China.[[15]](https://en.wikipedia.org/wiki/Rose#cite_note-15) Among the old Chinese garden roses, the Old Blush group is the most primitive, while newer groups are the most diverse.[[16]](https://en.wikipedia.org/wiki/Rose#cite_note-16)
#
# ### Genome
#
# A study of the patterns of [natural selection](https://en.wikipedia.org/wiki/Natural_selection "Natural selection") in the [genome](https://en.wikipedia.org/wiki/Genome "Genome") of roses indicated that [genes](https://en.wikipedia.org/wiki/Gene "Gene") related to [DNA damage repair](https://en.wikipedia.org/wiki/DNA_repair "DNA repair") and stress adaptation have been positively selected, likely during their domestication.[[17]](https://en.wikipedia.org/wiki/Rose#cite_note-Li2018-17) This rapid evolution may reflect an adaptation to genome confliction resulting from frequent intra- and inter-species hybridization and switching environmental conditions of growth.[[17]](https://en.wikipedia.org/wiki/Rose#cite_note-Li2018-17)
#
# ### Species
#
# [![Image 9](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Redoute_-_Rosa_gallica_purpuro-violacea_magna.jpg/250px-Redoute_-_Rosa_gallica_purpuro-violacea_magna.jpg)](https://en.wikipedia.org/wiki/File:Redoute_-_Rosa_gallica_purpuro-violacea_magna.jpg)
#
# _Rosa gallica_ 'Evêque', painted by [Redouté](https://en.wikipedia.org/wiki/Pierre-Joseph_Redout%C3%A9 "Pierre-Joseph Redouté")
#
# The genus _Rosa_ is composed of 140–180 species and divided into four subgenera:[[18]](https://en.wikipedia.org/wiki/Rose#cite_note-18)
#
# *   _Hulthemia_ (formerly _Simplicifoliae_, meaning "with single leaves") containing two species from [Southwest Asia](https://en.wikipedia.org/wiki/Southwest_Asia "Southwest Asia"), _[Rosa persica](https://en.wikipedia.org/wiki/Rosa\_persica "Rosa persica")_ and _[Rosa berberifolia](https://en.wikipedia.org/w/index.php?title=Rosa\_berberifolia&action=edit&redlink=1 "Rosa berberifolia (page does not exist)")_, which are the only roses without [compound leaves](https://en.wikipedia.org/wiki/Compound_leaves "Compound leaves") or [stipules](https://en.wikipedia.org/wiki/Stipule "Stipule").[[19]](https://en.wikipedia.org/wiki/Rose#cite_note-19)
# *   _Hesperrhodos_ (from the [Greek](https://en.wikipedia.org/wiki/Greek_(language) "Greek (language)") for "western rose") contains _[Rosa minutifolia](https://en.wikipedia.org/wiki/Rosa\_minutifolia "Rosa minutifolia")_ and _[Rosa stellata](https://en.wikipedia.org/wiki/Rosa\_stellata "Rosa stellata")_, from [North America](https://en.wikipedia.org/wiki/North_America "North America").
# *   _Platyrhodon_ (from the [Greek](https://en.wikipedia.org/wiki/Greek_(language) "Greek (language)") for "flaky rose", referring to flaky bark) with one species from east Asia, _[Rosa roxburghii](https://en.wikipedia.org/wiki/Rosa\_roxburghii "Rosa roxburghii")_ (also known as the chestnut rose).
# *   _Rosa_ (the [type](https://en.wikipedia.org/wiki/Biological_type "Biological type") subgenus, sometimes incorrectly called _Eurosa_) containing all the other roses. This subgenus is subdivided into 11 sections.
#     *   _Banksianae_– white and yellow flowered roses from China.
#     *   _Bracteatae_– three species, two from China and one from India.
#     *   _[Caninae](https://en.wikipedia.org/wiki/Rosa\_sect.\_Caninae "Rosa sect. Caninae")_– pink and white flowered species from Asia, Europe and [North Africa](https://en.wikipedia.org/wiki/North_Africa "North Africa").
#     *   _Carolinae_– white, pink, and bright pink flowered species all from North America.
#     *   _Chinensis_– white, pink, yellow, red and mixed-colour roses from China and [Burma](https://en.wikipedia.org/wiki/Burma "Burma").
#     *   _Gallicanae_– pink to crimson and striped flowered roses from western Asia and Europe.
#     *   _Gymnocarpae_– one species in western North America (_[Rosa gymnocarpa](https://en.wikipedia.org/wiki/Rosa\_gymnocarpa "Rosa gymnocarpa")_), others in east Asia.
#     *   _Laevigatae_– a single white flowered species from China.
#     *   _Pimpinellifoliae_– white, pink, bright yellow, mauve and striped roses from Asia and Europe.
#     *   _Rosa_ (syn. sect. _Cinnamomeae_)– white, pink, lilac, mulberry and red roses from everywhere but North Africa.
#     *   _Synstylae_– white, pink, and crimson flowered roses from all areas.
#
# Ecology
# -------
#
# Some birds, particularly [finches](https://en.wikipedia.org/wiki/Finch "Finch"), eat the seeds.
#
# ### Pests and diseases
#
# Wild roses are host plants for a number of pests and diseases. Many of these affect other plants, including other genera of the [Rosaceae](https://en.wikipedia.org/wiki/Rosaceae "Rosaceae").
#
# Cultivated roses are often subject to severe damage from [insect](https://en.wikipedia.org/wiki/Insect "Insect"), [arachnid](https://en.wikipedia.org/wiki/Arachnid "Arachnid") and [fungal](https://en.wikipedia.org/wiki/Fungal "Fungal") pests and diseases. In many cases they cannot be usefully grown without regular treatment to control these problems.
#
# Uses
# ----
#
# Roses are best known as [ornamental plants](https://en.wikipedia.org/wiki/Ornamental_plant "Ornamental plant") grown for their flowers in the [garden](https://en.wikipedia.org/wiki/Garden "Garden") and sometimes indoors. They have also been used for commercial perfumery and commercial cut flower crops. Some are used as landscape plants, for hedging and for other utilitarian purposes such as game cover and slope stabilization.
#
# ### Ornamental plants
#
# The majority of ornamental roses are hybrids that were bred for their flowers. A few, mostly species roses are grown for attractive or scented foliage (such as _[Rosa glauca](https://en.wikipedia.org/wiki/Rosa\_glauca "Rosa glauca")_ and _[R.rubiginosa](https://en.wikipedia.org/wiki/Rosa\_rubiginosa "Rosa rubiginosa")_), ornamental thorns (such as _[R.sericea](https://en.wikipedia.org/wiki/Rosa\_sericea "Rosa sericea")_) or for their showy fruit (such as _[R.moyesii](https://en.wikipedia.org/wiki/Rosa\_moyesii "Rosa moyesii")_).
#
# Ornamental roses have been cultivated for millennia, with the earliest known cultivation known to date from at least 500 BC in [Mediterranean](https://en.wikipedia.org/wiki/Mediterranean "Mediterranean") countries, [Persia](https://en.wikipedia.org/wiki/Persia "Persia"), and China.[[20]](https://en.wikipedia.org/wiki/Rose#cite_note-20) It is estimated that 30 to 35 thousand rose [hybrids](https://en.wikipedia.org/wiki/Hybrid_(biology) "Hybrid (biology)") and [cultivars](https://en.wikipedia.org/wiki/Cultivar "Cultivar") have been bred and selected for garden use as flowering plants.[[21]](https://en.wikipedia.org/wiki/Rose#cite_note-21) Most are [double-flowered](https://en.wikipedia.org/wiki/Double-flowered "Double-flowered") with many or all of the [stamens](https://en.wikipedia.org/wiki/Stamen "Stamen") having morphed into additional [petals](https://en.wikipedia.org/wiki/Petal "Petal").
#
# In the early 19th century the [Empress Josephine](https://en.wikipedia.org/wiki/Josephine_Beauharnais "Josephine Beauharnais") of France patronized the development of rose breeding at her gardens at [Malmaison](https://en.wikipedia.org/wiki/Ch%C3%A2teau_de_Malmaison "Château de Malmaison"). As long ago as 1840 a collection numbering over one thousand different [cultivars](https://en.wikipedia.org/wiki/Cultivar "Cultivar"), varieties and species was possible when a rosarium was planted by [Loddiges](https://en.wikipedia.org/wiki/Loddiges "Loddiges") nursery for [Abney Park Cemetery](https://en.wikipedia.org/wiki/Abney_Park_Cemetery "Abney Park Cemetery"), an early Victorian garden cemetery and arboretum in England.
#
# ### Cut flowers
#
# [![Image 10](https://upload.wikimedia.org/wikipedia/commons/thumb/0/00/Bouquet_de_roses_roses.jpg/250px-Bouquet_de_roses_roses.jpg)](https://en.wikipedia.org/wiki/File:Bouquet_de_roses_roses.jpg)
#
# Bouquet of pink roses
#
# Roses are a popular crop for both domestic and commercial [cut flowers](https://en.wikipedia.org/wiki/Cut_flowers "Cut flowers"). Generally they are harvested and cut when in bud, and held in refrigerated conditions until ready for display at their point of sale. The price of the roses depends partly on the characteristics of the rose itself, such as how long the stem is and how big the bloom is, and partly on factors about how it was grown, such as which country it was grown in.[[22]](https://en.wikipedia.org/wiki/Rose#cite_note-22)
#
# In temperate climates, cut roses are often grown in [greenhouses](https://en.wikipedia.org/wiki/Greenhouse "Greenhouse"), and in warmer countries they may also be grown under cover in order to ensure that the flowers are not damaged by weather and that pest and disease control can be carried out effectively. Significant quantities are grown in some tropical countries, and these are shipped by air to markets across the world.[[23]](https://en.wikipedia.org/wiki/Rose#cite_note-23)
#
# Some kind of roses are artificially coloured using dyed water, like [rainbow roses](https://en.wikipedia.org/wiki/Rainbow_rose "Rainbow rose").
#
# ### Perfume
#
# [![Image 11](https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Geraniol_structure.png/250px-Geraniol_structure.png)](https://en.wikipedia.org/wiki/File:Geraniol_structure.png)
#
# Geraniol (C
#
# 10 H
#
# 18 O)
#
# Rose perfumes are made from [rose oil](https://en.wikipedia.org/wiki/Rose_oil "Rose oil") (also called attar of roses), which is a mixture of volatile [essential oils](https://en.wikipedia.org/wiki/Essential_oil "Essential oil") obtained by steam distilling the crushed petals of roses. An associated product is [rose water](https://en.wikipedia.org/wiki/Rose_water "Rose water") which is used for cooking, cosmetics, medicine and religious practices. The production technique originated in [Persia](https://en.wikipedia.org/wiki/Iran "Iran")[[24]](https://en.wikipedia.org/wiki/Rose#cite_note-24) and then spread through [Arabia](https://en.wikipedia.org/wiki/Arabia "Arabia") and India, and more recently into [eastern Europe](https://en.wikipedia.org/wiki/Eastern_Europe "Eastern Europe"). In [Bulgaria](https://en.wikipedia.org/wiki/Bulgaria "Bulgaria"), [Iran](https://en.wikipedia.org/wiki/Iran "Iran") and [Germany](https://en.wikipedia.org/wiki/Germany "Germany"), damask roses ([_Rosa_ × _damascena_](https://en.wikipedia.org/wiki/Rosa_%C3%97_damascena "Rosa × damascena") 'Trigintipetala') are used. In other parts of the world [_Rosa_ × _centifolia_](https://en.wikipedia.org/wiki/Rosa_%C3%97_centifolia "Rosa × centifolia") is commonly used. The oil is transparent pale yellow or yellow-grey in colour. 'Rose Absolute' is solvent-extracted with hexane and produces a darker oil, dark yellow to orange in colour. The weight of oil extracted is about one three-thousandth to one six-thousandth of the weight of the flowers; for example, about two thousand flowers are required to produce one gram of oil.
#
# The main constituents of attar of roses are the fragrant [alcohols](https://en.wikipedia.org/wiki/Alcohol_(chemistry) "Alcohol (chemistry)")[geraniol](https://en.wikipedia.org/wiki/Geraniol "Geraniol") and L-[citronellol](https://en.wikipedia.org/wiki/Citronellol "Citronellol") and rose camphor, an odorless solid composed of [alkanes](https://en.wikipedia.org/wiki/Alkane "Alkane"), which separates from rose oil.[[25]](https://en.wikipedia.org/wiki/Rose#cite_note-25) β-[Damascenone](https://en.wikipedia.org/wiki/Damascenone "Damascenone") is also a significant contributor to the scent.
#
# ### Food and drink
#
# [![Image 12](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Rosa_rubiginosa_hips.jpg/250px-Rosa_rubiginosa_hips.jpg)](https://en.wikipedia.org/wiki/File:Rosa_rubiginosa_hips.jpg)
#
# _[Rosa rubiginosa](https://en.wikipedia.org/wiki/Rosa\_rubiginosa "Rosa rubiginosa")_ hips
#
# [![Image 13](https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Rose_fields_Vampula_1.jpg/250px-Rose_fields_Vampula_1.jpg)](https://en.wikipedia.org/wiki/File:Rose_fields_Vampula_1.jpg)
#
# Farming of _[Rosa rugosa](https://en.wikipedia.org/wiki/Rosa\_rugosa "Rosa rugosa")_
#
# In France, there is much use of [rose syrup](https://en.wikipedia.org/wiki/Rose_water "Rose water"), most commonly made from an extract of rose petals. In the [Indian subcontinent](https://en.wikipedia.org/wiki/Indian_subcontinent "Indian subcontinent"), [Rooh Afza](https://en.wikipedia.org/wiki/Rooh_Afza "Rooh Afza"), a concentrated [squash](https://en.wikipedia.org/wiki/Squash_(drink) "Squash (drink)") made with roses, is popular, as are rose-flavoured frozen desserts such as [ice cream](https://en.wikipedia.org/wiki/Ice_cream "Ice cream") and [kulfi](https://en.wikipedia.org/wiki/Kulfi "Kulfi").[[31]](https://en.wikipedia.org/wiki/Rose#cite_note-31)[[32]](https://en.wikipedia.org/wiki/Rose#cite_note-32)
#
# The flower stems and young shoots are edible, as are the petals (sans the white or green bases).[[26]](https://en.wikipedia.org/wiki/Rose#cite_note-Angier-1974-26) The latter are usually used as flavouring or to add their scent to food.[[33]](https://en.wikipedia.org/wiki/Rose#cite_note-33) Other minor uses include candied rose petals.[[34]](https://en.wikipedia.org/wiki/Rose#cite_note-34)
#
# Rose creams (rose-flavoured [fondant](https://en.wikipedia.org/wiki/Fondant_icing "Fondant icing") covered in [chocolate](https://en.wikipedia.org/wiki/Chocolate "Chocolate"), often topped with a crystallised rose petal) are a traditional English confectionery widely available from numerous producers in the UK.
#
# Under the American [Federal Food, Drug, and Cosmetic Act](https://en.wikipedia.org/wiki/Federal_Food,_Drug,_and_Cosmetic_Act "Federal Food, Drug, and Cosmetic Act"),[[35]](https://en.wikipedia.org/wiki/Rose#cite_note-35) there are only certain _Rosa_ species, varieties, and parts are listed as [generally recognized as safe](https://en.wikipedia.org/wiki/Generally_recognized_as_safe "Generally recognized as safe") (GRAS).
#
# *   Rose absolute: _Rosa alba_ L., _Rosa centifolia_ L., _Rosa damascena_ Mill., _Rosa gallica_ L., and vars. of these spp.
# *   Rose (otto of roses, attar of roses): Ditto
# *   Rose buds
# *   Rose flowers
# *   Rose fruit (hips)
# *   Rose leaves: _Rosa_ _spp._[[36]](https://en.wikipedia.org/wiki/Rose#cite_note-36)
#
# ### Art and symbolism
#
# [![Image 15](https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Rosa_sulfurea_001.JPG/250px-Rosa_sulfurea_001.JPG)](https://en.wikipedia.org/wiki/File:Rosa_sulfurea_001.JPG)
#
# _Rosa hemisphaerica_ (syn.: _R.sulphurea_), watercolor by Pierre-Joseph Redouté (1759–1840)
#
# The long cultural history of the rose has led to it being used often as a symbol. In [ancient Greece](https://en.wikipedia.org/wiki/Ancient_Greece "Ancient Greece"), the rose was closely associated with the goddess [Aphrodite](https://en.wikipedia.org/wiki/Aphrodite "Aphrodite").[[37]](https://en.wikipedia.org/wiki/Rose#cite_note-Cyrino2010-37)[[38]](https://en.wikipedia.org/wiki/Rose#cite_note-Clark2015-38) In the _[Iliad](https://en.wikipedia.org/wiki/Iliad "Iliad")_, Aphrodite protects the body of [Hector](https://en.wikipedia.org/wiki/Hector "Hector") using the "immortal oil of the rose"[[39]](https://en.wikipedia.org/wiki/Rose#cite_note-39)[[37]](https://en.wikipedia.org/wiki/Rose#cite_note-Cyrino2010-37) and the archaic Greek lyric poet [Ibycus](https://en.wikipedia.org/wiki/Ibycus "Ibycus") praises a beautiful youth sa
load.wikimedia.org/wikipedia/commons/thumb/d/d4/Plucking_the_Red_and_White_Roses%2C_by_Henry_Payne.jpg/250px-Plucking_the_Red_and_White_Roses%2C_by_Henry_Payne.jpg)](https://en.wikipedia.org/wiki/File:Plucking_the_Red_and_White_Roses,_by_Henry_Payne.jpg)
#
# Framed print after 1908 painting by [Henry Payne](https://en.wikipedia.org/wiki/Henry_Payne_(artist) "Henry Payne (artist)") of [the scene in the Temple Garden](https://en.wikipedia.org/wiki/Plucking_the_Red_and_White_Roses_in_the_Old_Temple_Gardens "Plucking the Red and White Roses in the Old Temple Gardens"), where supporters of the rival factions in the [Wars of the Roses](https://en.wikipedia.org/wiki/Wars_of_the_Roses "Wars of the Roses") pick either red or white roses
#
# Ever since the 1400s, the [Franciscans](https://en.wikipedia.org/wiki/Franciscans "Franciscans") have had a Crown Rosary of the [Seven Joys of the Blessed Virgin Mary](https://en.wikipedia.org/wiki/Seven_Joys_of_the_Virgin "Seven Joys of the Virgin").[[38]](https://en.wikipedia.org/wiki/Rose#cite_note-Clark2015-38) In the 1400s and 1500s, the [Carthusians](https://en.wikipedia.org/wiki/Carthusians "Carthusians") promoted the idea of sacred mysteries associated with the rose symbol and rose gardens.[[38]](https://en.wikipedia.org/wiki/Rose#cite_note-Clark2015-38)[Albrecht Dürer](https://en.wikipedia.org/wiki/Albrecht_D%C3%BCrer "Albrecht Dürer")'s painting _[The Feast of the Rosary](https://en.wikipedia.org/wiki/Feast\_of\_the\_Rosary "Feast of the Rosary")_ (1506) depicts the Virgin Mary distributing garlands of roses to her devotees.[[38]](https://en.wikipedia.org/wiki/Rose#cite_note-Clark2015-38)
#
# Roses symbolised the [Houses of York](https://en.wikipedia.org/wiki/White_Rose_of_York "White Rose of York") and [Lancaster](https://en.wikipedia.org/wiki/Red_Rose_of_Lancaster "Red Rose of Lancaster") in a conflict known as the [Wars of the Roses](https://en.wikipedia.org/wiki/Wars_of_the_Roses "Wars of the Roses"). Subsequently roses of the corresponding colours have been used a emblems for the English counties of [Yorkshire](https://en.wikipedia.org/wiki/Yorkshire "Yorkshire") and [Lancashire](https://en.wikipedia.org/wiki/Lancashire "Lancashire").
#
# The [Tudor rose](https://en.wikipedia.org/wiki/Tudor_rose "Tudor rose") combines the colours of the roses of York and Lancaster, and is an emblem of then [Tudor dynasty](https://en.wikipedia.org/wiki/Tudor_dynasty "Tudor dynasty") and of [England](https://en.wikipedia.org/wiki/England "England").
#
# Roses are a favored subject in art and appear in portraits, illustrations, on stamps, as ornaments or as architectural elements. The Luxembourg-born [Belgian](https://en.wikipedia.org/wiki/Belgium "Belgium") artist and botanist [Pierre-Joseph Redouté](https://en.wikipedia.org/wiki/Pierre-Joseph_Redout%C3%A9 "Pierre-Joseph Redouté") is known for his detailed watercolours of flowers, particularly roses.
#
# [Henri Fantin-Latour](https://en.wikipedia.org/wiki/Henri_Fantin-Latour "Henri Fantin-Latour") was also a prolific painter of still life, particularly flowers including roses. The rose 'Fantin-Latour' was named after the artist.
#
# Other impressionists including [Claude Monet](https://en.wikipedia.org/wiki/Claude_Monet "Claude Monet"), [Paul Cézanne](https://en.wikipedia.org/wiki/Paul_C%C3%A9zanne "Paul Cézanne") and [Pierre-Auguste Renoir](https://en.wikipedia.org/wiki/Pierre-Auguste_Renoir "Pierre-Auguste Renoir") have paintings of roses among their works. In the 19th century, for example, artists associated the city of [Trieste](https://en.wikipedia.org/wiki/Trieste "Trieste") with a certain rare white rose, and this rose developed as the city's symbol. It was not until 2021 that the rose, which was believed to be extinct, was rediscovered there.[[46]](https://en.wikipedia.org/wiki/Rose#cite_note-46)
# *   [![Image 19: Illustration of roses from a 14th-century edition of Tacuinum Sanitatis](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/31-primavera%2CTaccuino_Sanitatis%2C_Casanatense_4182..jpg/250px-31-primavera%2CTaccuino_Sanitatis%2C_Casanatense_4182..jpg)](https://en.wikipedia.org/wiki/File:31-primavera,Taccuino_Sanitatis,_Casanatense_4182..jpg "Illustration of roses from a 14th-century edition of Tacuinum Sanitatis")
#
# Illustration of roses from a 14th-century edition of _[Tacuinum Sanitatis](https://en.wikipedia.org/wiki/Tacuinum\_Sanitatis "Tacuinum Sanitatis")_
# *   [![Image 20: Codex Manesse illuminated with roses, illustrated between 1305 and 1340 in Zürich. It contains love songs in Middle High German](https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/Codex_Manesse_Rudolf_von_Neuenburg.jpg/250px-Codex_Manesse_Rudolf_von_Neuenburg.jpg)](https://en.wikipedia.org/wiki/File:Codex_Manesse_Rudolf_von_Neuenburg.jpg "Codex Manesse illuminated with roses, illustrated between 1305 and 1340 in Zürich. It contains love songs in Middle High German")
#
# [Codex Manesse](https://en.wikipedia.org/wiki/Codex_Manesse "Codex Manesse") illuminated with roses, illustrated between 1305 and 1340 in Zürich. It contains love songs in Middle High German
#
# ...
# 24.   **[^](https://en.wikipedia.org/wiki/Rose#cite_ref-24)**Nikbakht, Ali; Kafi, M.A. (January 2004). ["A study on the relationships between Iranian people and Damask rose (_Rosa damascena_) and its therapeutic and healing properties"](https://www.researchgate.net/publication/260293005). _Acta Horticulturae_. **790** (790): 251–4. [doi](https://en.wikipedia.org/wiki/Doi_(identifier) "Doi (identifier)"):[10.17660/ActaHortic.2008.790.36](https://doi.org/10.17660%2FActaHortic.2008.790.36). The origin of Damask rose is the Middle East and it is the national flower of Iran. Rose oil usage dates back to ancient civilization of Persia. Avicenna, the 10th century Persian physician, distilled its petals for medical purposes and commercial distillery existed in 1612 in Shiraz, Persia.
# 25.   **[^](https://en.wikipedia.org/wiki/Rose#cite_ref-25)**Stewart, D. (2005). [_The Chemistry Of Essential Oils Made Simple: God's Love Manifest In Molecules_](https://books.google.com/books?id=OJ3qKgNUljcC). Care. [ISBN](https://en.wikipedia.org/wiki/ISBN_(identifier) "ISBN (identifier)")[978-0-934426-99-2](https://en.wikipedia.org/wiki/Special:BookSources/978-0-934426-99-2 "Special:BookSources/978-0-934426-99-2").
# 26.   ^ [_**a**_](https://en.wikipedia.org/wiki/Rose#cite_ref-Angier-1974_26-0)[_**b**_](https://en.wikipedia.org/wiki/Rose#cite_ref-Angier-1974_26-1)[_**c**_](https://en.wikipedia.org/wiki/Rose#cite_ref-Angier-1974_26-2)[Angier, Bradford](https://en.wikipedia.org/wiki/Bradford_Angier "Bradford Angier") (1974). [_Field Guide to Edible Wild Plants_](https://archive.org/details/fieldguidetoedib00angi/page/186/mode/2up). Harrisburg, PA: Stackpole Books. p.186. [ISBN](https://en.wikipedia.org/wiki/ISBN_(identifier) "ISBN (identifier)")[0-8117-0616-8](https://en.wikipedia.org/wiki/Special:BookSources/0-8117-0616-8 "Special:BookSources/0-8117-0616-8"). [OCLC](https://en.wikipedia.org/wiki/OCLC_(identifier) "OCLC (identifier)")[799792](https://search.worldcat.org/oclc/799792).
# 27.   **[^](https://en.wikipedia.org/wiki/Rose#cite_ref-27)**["Rosa chinensis China Rose PFAF Plant Database"](http://pfaf.org/user/Plant.aspx?LatinName=Rosa%20chinensis). Pfaf.org. Retrieved 13 March 2013.
# 28.   **[^](https://en.wikipedia.org/wiki/Rose#cite_ref
# %%
json_url = JINA_READER_BASE + TARGET_URL
headers = {
    "X-Return-Format": "json" 
    # Optional: Add your API key for higher rate limits
    # "Authorization": "Bearer YOUR_JINA_API_KEY"
}

# %%
import requests
import json

json_url = "https://r.jina.ai/https://en.wikipedia.org/wiki/Rose"

# ✅ CORRECT HEADERS: Explicitly set the format to 'json'
headers = {
    "X-Return-Format": "json" 
    # Add your API key here if you want higher rate limits:
    # "Authorization": "Bearer YOUR_JINA_API_KEY" 
}

try:
    response = requests.get(json_url, headers=headers)
    
    # This line checks the status code (400, 404, 500, etc.)
    response.raise_for_status() 
    
    structured_data = response.json()
    
    print("--- Structured Content (JSON) ---")
    print(f"Title: {structured_data.get('data', {}).get('title')}")
    print(f"Extracted Content Length: {len(structured_data.get('data', {}).get('content', ''))} characters")

except requests.exceptions.RequestException as e:
    # This will catch the 400 error if it persists
    print(f"Error fetching JSON: {e}")
except json.JSONDecodeError:
    print("Error: Could not decode JSON response. The server may have returned plain HTML or an error message instead of JSON.")
# Out:
# Error fetching JSON: 400 Client Error: Bad Request for url: https://r.jina.ai/https://en.wikipedia.org/wiki/Rose

# %%
import requests
import json
import urllib.parse  # Good practice for encoding URLs
from dataclasses import dataclass
from typing import Dict, Any

@dataclass
class WebPageCotent:
    """
    Container for fetched web page content.

    Attributes:
        wiki_url: Original Wikipedia URL requested.
        title:    Extracted title from the response (or 'N/A' on failure).
        content:  Extracted main content/body (may be empty on failure).
    """
    wiki_url: str
    title: str
    content: str

def fetch_web_content(wiki_url: str) -> WebPageCotent:
    """
    Fetch content for a Wikipedia page via the Jina reader proxy.

    The function URL-encodes the provided Wikipedia URL, requests the Jina reader
    endpoint, and attempts to parse a JSON payload where content is expected under
    a 'data' object (i.e., {"data": {"title": "...", "content": "..."}}).

    If any network/HTTP/JSON parsing error occurs, it returns a WebPageCotent with
    title='N/A' and a short error message in `content`.

    Args:
        wiki_url: Full Wikipedia URL (e.g., "https://en.wikipedia.org/wiki/Rose").

    Returns:
        WebPageCotent: Dataclass containing the requested URL, title, and content.
    """
    # 1. URL-encode the target URL (best practice) and prepend the Jina reader base
    encoded_target_url: str = urllib.parse.quote(wiki_url, safe='')
    json_url: str = f"https://r.jina.ai/{encoded_target_url}"

    # 2. Use the standard 'Accept' header for JSON response
    headers: Dict[str, str] = {
        "Accept": "application/json"
    }

    print(f"Requesting URL: {json_url}")
    print(f"With Headers: {headers}")

    try:
        response = requests.get(json_url, headers=headers)
        response.raise_for_status()  # Check for HTTP errors (like 400, 404)

        # Decode the JSON response
        structured_data: Any = response.json()

        # Jina's JSON structure usually nests content under a 'data' object
        data: Dict[str, Any] = structured_data.get('data', {}) if isinstance(structured_data, dict) else {}

        # Access the clean content and title
        title: str = data.get('title', 'N/A')
        content: str = data.get('content', '')
        wiki_url = wiki_url  # preserve original variable per existing structure

    except (requests.RequestException, json.JSONDecodeError, ValueError) as e:
        title = 'N/A'
        content = f'Error fetching or parsing JSON response: {e}'
        wiki_url = wiki_url

    return WebPageCotent(
        wiki_url=wiki_url,
        title=title,
        content=content
    )

# %% [markdown]
# ## Append/Search Tool

# %%
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
from typing import List, Dict, Any


summary_storage: List[Dict[str, Any]] = []
class SearchAppendTool:
    """
    Minimal FAISS-backed semantic search helper that lets you append
    text summaries with custom integer IDs and query them locally.
    """

    def __init__(self) -> None:
        
        # Initialize the embedding model
        self.model: SentenceTransformer = SentenceTransformer("all-MiniLM-L6-v2")
        D: int = 384  # Dimension of the 'all-MiniLM-L6-v2' model

        # 1. Create the base index (supports incremental addition)
        base_index = faiss.IndexFlatIP(D)

        # 2. Wrap with IndexIDMap to enable custom integer IDs
        self.index: faiss.IndexIDMap = faiss.IndexIDMap(base_index)

        # Local storage to map IDs back to text/metadata
        self.next_available_id: int = 0

    def append_webpage_summary(self, summary: str, wiki_url: str, title: str) -> None:
        """
        Encode a single summary and append it to the FAISS index with a custom ID.

        Args:
            summary:  The text chunk/summary to store.
            wiki_url: Source URL for reference.
            title:    Title associated with the content.
        """
        # 1. Vectorize the text (normalize=True for cosine similarity with IP)
        vector = self.model.encode([summary], normalize_embeddings=True)

        # 2. Prepare the data for FAISS (float32, 2D array)
        vectors_to_add = vector.astype("float32")

        # FAISS requires a 1D int64 array of IDs
        ids_to_add = np.array([self.next_available_id], dtype=np.int64)

        # 3. Append the vector and custom ID to the index
        self.index.add_with_ids(vectors_to_add, ids_to_add)

        # 4. Update local storage (ID -> item mapping)
        summary_storage.append(
            {"id": self.next_available_id, "summary": summary, "wiki_url": wiki_url, "title": title}
        )

        # Increment ID counter (was a no-op previously)
        self.next_available_id += 1

        # Keep original behavior: no return value
        return

    def search_local(self, query: str) -> List[Dict[str, Any]]:
        """
        Perform a semantic search over locally indexed summaries.

        Args:
            query: The search query string.

        Returns:
            A list of stored items (dicts) that match best, up to top-3,
            each including: {"id", "summary", "wiki_url", "title"}.
        """
        # 1. Vectorize the query
        query_vector = self.model.encode([query], normalize_embeddings=True).astype("float32")

        # 2. Perform the search (top-3)
        distances, indices = self.index.search(query_vector, 3)

        # 3. Retrieve the corresponding summaries
        results: List[Dict[str, Any]] = []
        for idx in indices[0]:
            if idx == -1:
                continue  # Skip empty slots
            # Find the summary in local storage
            for item in summary_storage:
                if item["id"] == int(idx):
                    results.append(item)
                    break

        return results

# %% [markdown]
# ## Pydantic AI

# %%
from pydantic_ai import Agent
from pydantic import BaseModel, Field

from typing import List

# %%
from pydantic_ai.messages import FunctionToolCallEvent, FunctionToolResultEvent

class NamedCallback:

    def __init__(self, agent):
        self.agent_name = agent.name

    async def print_function_calls(self, ctx, event):
        # Detect nested streams
        if hasattr(event, "__aiter__"):
            async for sub in event:
                await self.print_function_calls(ctx, sub)
            return

        if isinstance(event, FunctionToolCallEvent):
            print("CALL →", event.part.tool_name, event.part.args_as_dict(), event.tool_call_id)
        elif isinstance(event, FunctionToolResultEvent):
            print("RES  ←", event.result.tool_name, event.tool_call_id, event.result.content)

    async def __call__(self, ctx, event):
        return await self.print_function_calls(ctx, event)

# %%
instructions = """
You are an AI assistant that fetches, summarizes, and answers questions about Wikipedia articles.

### Tools
- **fetch_web_content(url)**: Retrieve a Wikipedia article’s content and title.
- **append_webpage_summary(summary, wiki_url, title)**: Store a short summary in the local knowledge base.
- **search_local(query)**: Search stored summaries for relevant information.

### Workflow
1. When a user provides a Wikipedia URL:
   - Fetch the article with `fetch_web_content`.
   - Summarize it in 2–4 sentences (clear, factual, neutral).
   - Store it using `append_webpage_summary` (include URL and title).
2. When a user asks a question:
   - Use `search_local` to find relevant summaries.
   - Combine information from the top results to form a concise, factual answer.
   - **Always include references** — each answer must cite the **Wikipedia page title** and **URL** for every source used.

### Behavior Guidelines
- Be accurate, concise, and neutral.
- Prefer existing stored summaries before fetching new data.
- If unsure, explain reasoning clearly.
- Example reference format: “According to *Rose* (https://en.wikipedia.org/wiki/Rose), ...”
""".strip()

# %%
search_tools = SearchAppendTool()

# %%
first_agent = Agent(
    name='clarifier',
    instructions=instructions,
    tools=[search_tools.append_webpage_summary, search_tools.search_local, fetch_web_content],
    model='gpt-4o-mini',
)

first_agent_callback = NamedCallback(first_agent)

# %%
question = "What is this page about? https://en.wikipedia.org/wiki/Capybara"

# %%
clarifier_results1 = await first_agent.run(
    user_prompt=question,
    event_stream_handler=first_agent_callback
)
# Out:
# CALL → fetch_web_content {'wiki_url': 'https://en.wikipedia.org/wiki/Capybara'} call_vT807v29wZhhNlgVDbBIt40v
# Requesting URL: https://r.jina.ai/https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FCapybara
# With Headers: {'Accept': 'application/json'}
# RES  ← fetch_web_content call_vT807v29wZhhNlgVDbBIt40v WebPageCotent(wiki_url='https://en.wikipedia.org/wiki/Capybara', title='Capybara', content='[![Image 1: This is a good article. Click here for more information.](https://upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/20px-Symbol_support_vote.svg.png)](https://en.wikipedia.org/wiki/Wikipedia:Good_articles* "This is a good article. Click here for more information.")\n\n[![Image 2: Page semi-protected](https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png)](https://en.wikipedia.org/wiki/Wikipedia:Protection_policy#semi "This article is semi-protected until March 17, 2028 at 19:23 UTC.")\n\nFrom Wikipedia, the free encyclopedia\n\n| Capybara |\n| --- |\n| [![Image 3](https://upload.wikimedia.org/wikipedia/commons/thumb/3/34/Hydrochoeris_hydrochaeris_in_Brazil_in_Petr%C3%B3polis%2C_Rio_de_Janeiro%2C_Brazil_09.jpg/250px-Hydrochoeris_hydrochaeris_in_Brazil_in_Petr%C3%B3polis%2C_Rio_de_Janeiro%2C_Brazil_09.jpg)](https://en.wikipedia.org/wiki/File:Hydrochoeris_hydrochaeris_in_Brazil_in_Petr%C3%B3polis,_Rio_de_Janeiro,_Brazil_09.jpg) |\n| In [Petrópolis](https://en.wikipedia.org/wiki/Petr%C3%B3polis "Petrópolis"), Brazil |\n| [Conservation status](https://en.wikipedia.org/wiki/Conservation_status "Conservation status") |\n| ![Image 4](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Status_iucn3.1_LC.svg/250px-Status_iucn3.1_LC.svg.png) [Least Concern](https://en.wikipedia.org/wiki/Least_Concern "Least Concern")([IUCN 3.1](https://en.wikipedia.org/wiki/IUCN_Red_List "IUCN Red List"))[[1]](https://en.wikipedia.org/wiki/Capybara#cite_note-iucn_status_19_November_2021-1) |\n| [Scientific classification](https://en.wikipedia.org/wiki/Taxonomy_(biology) "Taxonomy (biology)")[![Image 5: Edit this classification](https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/OOjs_UI_icon_edit-ltr.svg/20px-OOjs_UI_icon_edit-ltr.svg.png)](https://en.wikipedia.org/wiki/Template:Taxonomy/Hydrochoerus "Edit this classification") |\n| Kingdom: | [Animalia](https://en.wikipedia.org/wiki/Animal "Animal") |\n| Phylum: | [Chordata](https://en.wikipedia.org/wiki/Chordate "Chordate") |\n| Class: | [Mammalia](https://en.wikipedia.org/wiki/Mammal "Mammal") |\n| Order: | [Rodentia](https://en.wikipedia.org/wiki/Rodent "Rodent") |\n| Family: | [Caviidae](https://en.wikipedia.org/wiki/Caviidae "Caviidae") |\n| Genus: | [_Hydrochoerus_](https://en.wikipedia.org/wiki/Hydrochoerus "Hydrochoerus") |\n| Species: | _**H.hydrochaeris**_ |\n| [Binomial name](https://en.wikipedia.org/wiki/Binomial_nomenclature "Binomial nomenclature") |\n| **_Hydrochoerus hydrochaeris_** ([Linnaeus](https://en.wikipedia.org/wiki/Carl_Linnaeus "Carl Linnaeus"), [1766](https://en.wikipedia.org/wiki/12th_edition_of_Systema_Naturae "12th edition of Systema Naturae")) |\n| [![Image 6](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Capybara_range.svg/250px-Capybara_range.svg.png)](https://en.wikipedia.org/wiki/File:Capybara_range.svg) |\n| Native range |\n| [Synonyms](https://en.wikipedia.org/wiki/Synonym_(taxonomy) "Synonym (taxonomy)") |\n| _Sus hydrochaeris_ Linnaeus,1766 |\n\nThe **capybara**[[a]](https://en.wikipedia.org/wiki/Capybara#cite_note-2) or **greater capybara** (_**Hydrochoerus hydrochaeris**_) is the largest living rodent,[[2]](https://en.wikipedia.org/wiki/Capybara#cite_note-3) native to [South America](https://en.wikipedia.org/wiki/South_America "South America"). It is a member of the genus _[Hydrochoerus](https://en.wikipedia.org/wiki/Hydrochoerus "Hydrochoerus")_. Its close relatives include [guinea pigs](https://en.wikipedia.org/wiki/Cavia "Cavia") and [rock cavies](https://en.wikipedia.org/wiki/Kerodon "Kerodon"), and it is more distantly related to the [agouti](https://en.wikipedia.org/wiki/Agouti "Agouti"), the [chinchilla](https://en.wikipedia.org/wiki/Chinchilla "Chinchilla"), and the [nutria](https://en.wikipedi ...
# CALL → append_webpage_summary {'summary': "The capybara (Hydrochoerus hydrochaeris) is the world's largest rodent, native to South America. It thrives in savannas and dense forests near water sources and is known for its social behavior, often living in groups of 10-20 individuals that can swell to larger numbers in certain seasons. Capybaras primarily eat grasses and aquatic plants and are semi-aquatic, being excellent swimmers. They are not considered threatened and have adapted well to some urban environments, where they are sometimes kept as pets.", 'wiki_url': 'https://en.wikipedia.org/wiki/Capybara', 'title': 'Capybara'} call_LZgvAmSei1TwZTukEZL7Sd5u
# RES  ← append_webpage_summary call_LZgvAmSei1TwZTukEZL7Sd5u None

# %%
print(clarifier_results1.output)
# Out:
# The **capybara** (*Hydrochoerus hydrochaeris*) is the largest rodent in the world, indigenous to South America. It inhabits savannas and dense forests, living near bodies of water, and is known for its social nature, typically found in groups of 10-20, but can form larger herds. Capybaras primarily feed on grasses and aquatic plants, and they are semi-aquatic, displaying excellent swimming abilities. Despite hunting pressures in certain areas, they are not considered endangered and have adapted successfully to some urban environments where they can even be kept as pets (source: *Capybara* - https://en.wikipedia.org/wiki/Capybara).

# %%
summary_storage
# Out:
# [{'id': 0,
#   'summary': "The capybara (Hydrochoerus hydrochaeris) is the world's largest rodent, native to South America. It thrives in savannas and dense forests near water sources and is known for its social behavior, often living in groups of 10-20 individuals that can swell to larger numbers in certain seasons. Capybaras primarily eat grasses and aquatic plants and are semi-aquatic, being excellent swimmers. They are not considered threatened and have adapted well to some urban environments, where they are sometimes kept as pets.",
#   'wiki_url': 'https://en.wikipedia.org/wiki/Capybara',
#   'title': 'Capybara'}]

# %%
question=""" Index each of this wiki pages to the local vector DB:
— https://en.wikipedia.org/wiki/Lesser_capybara
— https://en.wikipedia.org/wiki/Hydrochoerus

 — https://en.wikipedia.org/wiki/Neochoerus

— https://en.wikipedia.org/wiki/Caviodon

— https://en.wikipedia.org/wiki/Neochoerus_aesopi
"""

# %%
clarifier_results1 = await first_agent.run(
    user_prompt=question,
    event_stream_handler=first_agent_callback
)
# Out:
# CALL → fetch_web_content {'wiki_url': 'https://en.wikipedia.org/wiki/Lesser_capybara'} call_siBHCbK9RhbXljFF3j0a9HmH
# CALL → fetch_web_content {'wiki_url': 'https://en.wikipedia.org/wiki/Hydrochoerus'} call_RTnNeDQsqUGFrAoxJBGrP1iS
# CALL → fetch_web_content {'wiki_url': 'https://en.wikipedia.org/wiki/Neochoerus'} call_goXm2x1ZQhaYgWpiNtLZMMc4
# CALL → fetch_web_content {'wiki_url': 'https://en.wikipedia.org/wiki/Caviodon'} call_ohq7whLv29QgNTlpIlupogyY
# CALL → fetch_web_content {'wiki_url': 'https://en.wikipedia.org/wiki/Neochoerus_aesopi'} call_Ea684bs4Ff2YA5Zxwk6pmihJ
# Requesting URL: https://r.jina.ai/https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FLesser_capybara
# With Headers: {'Accept': 'application/json'}
# Requesting URL: https://r.jina.ai/https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FHydrochoerus
# With Headers: {'Accept': 'application/json'}
# Requesting URL: https://r.jina.ai/https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FNeochoerus
# With Headers: {'Accept': 'application/json'}
# Requesting URL: https://r.jina.ai/https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FCaviodon
# With Headers: {'Accept': 'application/json'}
# Requesting URL: https://r.jina.ai/https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FNeochoerus_aesopi
# With Headers: {'Accept': 'application/json'}
# RES  ← fetch_web_content call_Ea684bs4Ff2YA5Zxwk6pmihJ WebPageCotent(wiki_url='https://en.wikipedia.org/wiki/Neochoerus_aesopi', title='Neochoerus aesopi', content='Neochoerus aesopi - Wikipedia\n\n===============\n[Jump to content](https://en.wikipedia.org/wiki/Neochoerus_aesopi#bodyContent)\n\n- [x] Main menu \n\nMain menu\n\nmove to sidebar hide\n\n Navigation \n\n*   [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page [alt-z]")\n*   [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")\n*   [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")\n*   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [alt-x]")\n*   [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")\n*   [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")\n\n Contribute \n\n*   [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")\n*   [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")\n*   [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")\n*   [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [alt-r]")\n*   [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")\n*   [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)\n\n[![Image 2](https://en.wikipedia.org/static/images/icons/wikipedia.png)![Image 3: Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg)![Image 4: The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg)](https://en.wikipedia.org/wiki/Main_Page)\n\n[Search](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia [alt-f]")\n\nSearch\n\n- [x] Appearance \n\nAppearance\n\nmove to sidebar hide\n\nText\n\n*   Small  Standard  Large   \n\nThis page always uses small font size\n\nWidth\n\n*   Standard  Wide   \n\nThe content is as wide as possible for your browser window.\n\nColor (beta)\n\n*   Automatic  Light  Dark   \n\nThis page is always in light mode.\n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Neochoerus+aesopi "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Neochoerus+aesopi "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n- [x] Personal tools \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Neochoerus+aesopi "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Neochoerus+aesopi "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n Pages for logged out editors [learn more](https://en.wikipedia.org/wiki/Help:Introduction)\n\n*   [Contributions](https://en.wikipedia.org/wiki/Special:MyContributions "A list of edits made from this IP address [alt-y]")\n*   [Talk](https://en.wikipedia.org/wiki/Special:MyTalk "Discussion about edits from this IP address [alt-n]")\n\n Wikipedia was just a dream. \n\nOctober 27: Readers in the United States deserve an explanation. \n\nPlease don\'t skip this 1-minute read. It\'s Monday, October 27, and if you\'re like us, you\'ve used Wikipedia countless times. To settle an argument w ...
# RES  ← fetch_web_content call_siBHCbK9RhbXljFF3j0a9HmH WebPageCotent(wiki_url='https://en.wikipedia.org/wiki/Lesser_capybara', title='Lesser capybara', content='Lesser capybara - Wikipedia\n\n===============\n[Jump to content](https://en.wikipedia.org/wiki/Lesser_capybara#bodyContent)\n\n- [x] Main menu \n\nMain menu\n\nmove to sidebar hide\n\n Navigation \n\n*   [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page [alt-z]")\n*   [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")\n*   [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")\n*   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [alt-x]")\n*   [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")\n*   [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")\n\n Contribute \n\n*   [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")\n*   [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")\n*   [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")\n*   [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [alt-r]")\n*   [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")\n*   [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)\n\n[![Image 7](https://en.wikipedia.org/static/images/icons/wikipedia.png)![Image 8: Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg)![Image 9: The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg)](https://en.wikipedia.org/wiki/Main_Page)\n\n[Search](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia [alt-f]")\n\nSearch\n\n- [x] Appearance \n\nAppearance\n\nmove to sidebar hide\n\nText\n\n*   Small  Standard  Large   \n\nThis page always uses small font size\n\nWidth\n\n*   Standard  Wide   \n\nThe content is as wide as possible for your browser window.\n\nColor (beta)\n\n*   Automatic  Light  Dark   \n\nThis page is always in light mode.\n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Lesser+capybara "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Lesser+capybara "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n- [x] Personal tools \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Lesser+capybara "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Lesser+capybara "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n Pages for logged out editors [learn more](https://en.wikipedia.org/wiki/Help:Introduction)\n\n*   [Contributions](https://en.wikipedia.org/wiki/Special:MyContributions "A list of edits made from this IP address [alt-y]")\n*   [Talk](https://en.wikipedia.org/wiki/Special:MyTalk "Discussion about edits from this IP address [alt-n]")\n\n Wikipedia was just a dream. \n\nOctober 27: Readers in the United States deserve an explanation. \n\nPlease don\'t skip this 1-minute read. It\'s Monday, October 27, and if you\'re like us, you\'ve used Wikipedia countless times. To settle an argument with a friend. To ...
# RES  ← fetch_web_content call_goXm2x1ZQhaYgWpiNtLZMMc4 WebPageCotent(wiki_url='https://en.wikipedia.org/wiki/Neochoerus', title='Neochoerus', content='Neochoerus - Wikipedia\n\n===============\n[Jump to content](https://en.wikipedia.org/wiki/Neochoerus#bodyContent)\n\n- [x] Main menu \n\nMain menu\n\nmove to sidebar hide\n\n Navigation \n\n*   [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page [alt-z]")\n*   [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")\n*   [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")\n*   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [alt-x]")\n*   [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")\n*   [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")\n\n Contribute \n\n*   [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")\n*   [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")\n*   [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")\n*   [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [alt-r]")\n*   [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")\n*   [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)\n\n[![Image 4](https://en.wikipedia.org/static/images/icons/wikipedia.png)![Image 5: Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg)![Image 6: The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg)](https://en.wikipedia.org/wiki/Main_Page)\n\n[Search](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia [alt-f]")\n\nSearch\n\n- [x] Appearance \n\nAppearance\n\nmove to sidebar hide\n\nText\n\n*   Small  Standard  Large   \n\nThis page always uses small font size\n\nWidth\n\n*   Standard  Wide   \n\nThe content is as wide as possible for your browser window.\n\nColor (beta)\n\n*   Automatic  Light  Dark   \n\nThis page is always in light mode.\n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Neochoerus "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Neochoerus "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n- [x] Personal tools \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Neochoerus "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Neochoerus "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n Pages for logged out editors [learn more](https://en.wikipedia.org/wiki/Help:Introduction)\n\n*   [Contributions](https://en.wikipedia.org/wiki/Special:MyContributions "A list of edits made from this IP address [alt-y]")\n*   [Talk](https://en.wikipedia.org/wiki/Special:MyTalk "Discussion about edits from this IP address [alt-n]")\n\n[![Image 7](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Wiki_Loves_Monuments_Logo_notext.svg/70px-Wiki_Loves_Monuments_Logo_notext.svg.png) Photograph a historic site, help Wikipedia, and win a prize. Participate in the world\'s largest photography competition this month!Learn more ![Image 8](ht ...
# RES  ← fetch_web_content call_ohq7whLv29QgNTlpIlupogyY WebPageCotent(wiki_url='https://en.wikipedia.org/wiki/Caviodon', title='Caviodon', content='Caviodon - Wikipedia\n\n===============\n[Jump to content](https://en.wikipedia.org/wiki/Caviodon#bodyContent)\n\n- [x] Main menu \n\nMain menu\n\nmove to sidebar hide\n\n Navigation \n\n*   [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page [alt-z]")\n*   [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")\n*   [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")\n*   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [alt-x]")\n*   [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")\n*   [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")\n\n Contribute \n\n*   [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")\n*   [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")\n*   [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")\n*   [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [alt-r]")\n*   [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")\n*   [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)\n\n[![Image 2](https://en.wikipedia.org/static/images/icons/wikipedia.png)![Image 3: Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg)![Image 4: The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg)](https://en.wikipedia.org/wiki/Main_Page)\n\n[Search](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia [alt-f]")\n\nSearch\n\n- [x] Appearance \n\nAppearance\n\nmove to sidebar hide\n\nText\n\n*   Small  Standard  Large   \n\nThis page always uses small font size\n\nWidth\n\n*   Standard  Wide   \n\nThe content is as wide as possible for your browser window.\n\nColor (beta)\n\n*   Automatic  Light  Dark   \n\nThis page is always in light mode.\n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Caviodon "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Caviodon "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n- [x] Personal tools \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Caviodon "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Caviodon "You\'re encouraged to log in; however, it\'s not mandatory. [alt-o]")\n\n Pages for logged out editors [learn more](https://en.wikipedia.org/wiki/Help:Introduction)\n\n*   [Contributions](https://en.wikipedia.org/wiki/Special:MyContributions "A list of edits made from this IP address [alt-y]")\n*   [Talk](https://en.wikipedia.org/wiki/Special:MyTalk "Discussion about edits from this IP address [alt-n]")\n\n[![Image 5](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Wiki_Loves_Monuments_Logo_notext.svg/70px-Wiki_Loves_Monuments_Logo_notext.svg.png) Photograph a historic site, help Wikipedia, and win a prize. Participate in the world\'s largest photography competition this month!Learn more ![Image 6](https://en.wikiped ...
# RES  ← fetch_web_content call_RTnNeDQsqUGFrAoxJBGrP1iS WebPageCotent(wiki_url='https://en.wikipedia.org/wiki/Hydrochoerus', title='Hydrochoerus', content='From Wikipedia, the free encyclopedia\n\n| _Hydrochoerus_ Temporal range: [Pliocene](https://en.wikipedia.org/wiki/Pliocene "Pliocene") - [Recent](https://en.wikipedia.org/wiki/Holocene "Holocene") ~3.
=Hydrochoerus\\_ballesterensis&action=edit&redlink=1 "Hydrochoerus ballesterensis (page does not exist)")_ [†](https://en.wikipedia.org/wiki/Extinct "Extinct")_[H. gaylordi](https://en.wikipedia.org/wiki/Hydrochoerus\\_gaylordi "Hydrochoerus gaylordi")_ [†](https://en.wikipedia.org/wiki/Extinct "Extinct")_[H. hesperotiganites](https://en.wikipedia.org/wiki/Hydrochoerus\\_hesperotiganites "Hydrochoerus hesperotiganites")_ _[H. hydrochaeris](https://en.wikipedia.org/wiki/Hydrochoerus\\_hydrochaeris "Hydrochoerus hydrochaeris")_ _[H. isthmius](https://en.wikipedia.org/wiki/Hydrochoerus\\_isthmius "Hydrochoerus isthmius")_ |\n| [![Image 3](https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/Capybara-ranges.png/250px-Capybara-ranges.png)](https://en.wikipedia.org/wiki/File:Capybara-ranges.png) |\n| Ranges of [capybara](https://en.wikipedia.org/w ...
# CALL → append_webpage_summary {'summary': 'The Lesser Capybara (_Hydrochoerus isthmius_) is a large semi-aquatic rodent native to parts of South America, particularly Panama and Colombia. It is smaller than the common capybara and primarily inhabits aquatic environments, where it grazes on grasses and other plants. This species has been classified as data deficient due to limited information about its population dynamics and ecology.', 'wiki_url': 'https://en.wikipedia.org/wiki/Lesser_capybara', 'title': 'Lesser capybara'} call_77AiVgjTPZo9euMRHHtoQjdA
# CALL → append_webpage_summary {'summary': 'The genus _Hydrochoerus_ includes two extant species: the Common Capybara (_Hydrochoerus hydrochaeris_) and the Lesser Capybara (_Hydrochoerus isthmius_). These are the largest living rodents, found in semi-aquatic environments across South America, and are also known for their social behavior and dietary habits focused on grasses.', 'wiki_url': 'https://en.wikipedia.org/wiki/Hydrochoerus', 'title': 'Hydrochoerus'} call_B3HzxVGk8CCGDmJVAZgnbcFm
# CALL → append_webpage_summary {'summary': '_Neochoerus_ is an extinct genus of rodents that were closely related to modern capybaras. Fossils of _Neochoerus_ have been found across North America and South America, indicating a wide distribution during the Pleistocene between approximately 2.5 million and 12,000 years ago. The genus includes several species such as _Neochoerus aesopi_, known for its relatively large size compared to its modern relatives.', 'wiki_url': 'https://en.wikipedia.org/wiki/Neochoerus', 'title': 'Neochoerus'} call_Bzh6Hs96ihw411oopLTSOkD9
# CALL → append_webpage_summary {'summary': '_Caviodon_ is an extinct genus of rodents from the Late Miocene to Late Pliocene. Related to modern capybaras, fossils have been unearthed in Argentina, Brazil, and Venezuela. The genus includes several species which indicate a diverse adaptation to various habitats during its existence.', 'wiki_url': 'https://en.wikipedia.org/wiki/Caviodon', 'title': 'Caviodon'} call_GapzHDvVFNTLnzqWtny1mEZq
# CALL → append_webpage_summary {'summary': '_Neochoerus aesopi_ is an extinct rodent species from the Pleistocene epoch, closely related to modern capybaras. This species lived in North America, and its fossils have been discovered primarily in states like Florida and South Carolina, indicating its relatively large size at about 80 kg. It is recognized to have gone extinct roughly 12,000 years ago during the Late Pleistocene.', 'wiki_url': 'https://en.wikipedia.org/wiki/Neochoerus_aesopi', 'title': 'Neochoerus aesopi'} call_2KaLOy1fJ7FXVO1Ct83s5GhF
# RES  ← append_webpage_summary call_B3HzxVGk8CCGDmJVAZgnbcFm None
# RES  ← append_webpage_summary call_77AiVgjTPZo9euMRHHtoQjdA None
# RES  ← append_webpage_summary call_GapzHDvVFNTLnzqWtny1mEZq None
# RES  ← append_webpage_summary call_2KaLOy1fJ7FXVO1Ct83s5GhF None
# RES  ← append_webpage_summary call_Bzh6Hs96ihw411oopLTSOkD9 None

# %%
summary_storage
# Out:
# [{'id': 0,
#   'summary': "The capybara (Hydrochoerus hydrochaeris) is the world's largest rodent, native to South America. It thrives in savannas and dense forests near water sources and is known for its social behavior, often living in groups of 10-20 individuals that can swell to larger numbers in certain seasons. Capybaras primarily eat grasses and aquatic plants and are semi-aquatic, being excellent swimmers. They are not considered threatened and have adapted well to some urban environments, where they are sometimes kept as pets.",
#   'wiki_url': 'https://en.wikipedia.org/wiki/Capybara',
#   'title': 'Capybara'},
#  {'id': 1,
#   'summary': 'The genus _Hydrochoerus_ includes two extant species: the Common Capybara (_Hydrochoerus hydrochaeris_) and the Lesser Capybara (_Hydrochoerus isthmius_). These are the largest living rodents, found in semi-aquatic environments across South America, and are also known for their social behavior and dietary habits focused on grasses.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Hydrochoerus',
#   'title': 'Hydrochoerus'},
#  {'id': 2,
#   'summary': 'The Lesser Capybara (_Hydrochoerus isthmius_) is a large semi-aquatic rodent native to parts of South America, particularly Panama and Colombia. It is smaller than the common capybara and primarily inhabits aquatic environments, where it grazes on grasses and other plants. This species has been classified as data deficient due to limited information about its population dynamics and ecology.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Lesser_capybara',
#   'title': 'Lesser capybara'},
#  {'id': 3,
#   'summary': '_Caviodon_ is an extinct genus of rodents from the Late Miocene to Late Pliocene. Related to modern capybaras, fossils have been unearthed in Argentina, Brazil, and Venezuela. The genus includes several species which indicate a diverse adaptation to various habitats during its existence.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Caviodon',
#   'title': 'Caviodon'},
#  {'id': 4,
#   'summary': '_Neochoerus aesopi_ is an extinct rodent species from the Pleistocene epoch, closely related to modern capybaras. This species lived in North America, and its fossils have been discovered primarily in states like Florida and South Carolina, indicating its relatively large size at about 80 kg. It is recognized to have gone extinct roughly 12,000 years ago during the Late Pleistocene.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Neochoerus_aesopi',
#   'title': 'Neochoerus aesopi'},
#  {'id': 5,
#   'summary': '_Neochoerus_ is an extinct genus of rodents that were closely related to modern capybaras. Fossils of _Neochoerus_ have been found across North America and South America, indicating a wide distribution during the Pleistocene between approximately 2.5 million and 12,000 years ago. The genus includes several species such as _Neochoerus aesopi_, known for its relatively large size compared to its modern relatives.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Neochoerus',
#   'title': 'Neochoerus'}]

# %%
question=""" What are threats to capybara populations?"""

# %%
clarifier_results1 = await first_agent.run(
    user_prompt=question,
    event_stream_handler=first_agent_callback
)
# Out:
# CALL → search_local {'query': 'capybara threats population'} call_AjwLlZoydSYQ2WvgT9Jfcjam
# RES  ← search_local call_AjwLlZoydSYQ2WvgT9Jfcjam [{'id': 0, 'summary': "The capybara (Hydrochoerus hydrochaeris) is the world's largest rodent, native to South America. It thrives in savannas and dense forests near water sources and is known for its social behavior, often living in groups of 10-20 individuals that can swell to larger numbers in certain seasons. Capybaras primarily eat grasses and aquatic plants and are semi-aquatic, being excellent swimmers. They are not considered threatened and have adapted well to some urban environments, where they are sometimes kept as pets.", 'wiki_url': 'https://en.wikipedia.org/wiki/Capybara', 'title': 'Capybara'}, {'id': 2, 'summary': 'The Lesser Capybara (_Hydrochoerus isthmius_) is a large semi-aquatic rodent native to parts of South America, particularly Panama and Colombia. It is smaller than the common capybara and primarily inhabits aquatic environments, where it grazes on grasses and other plants. This species has been classified as data deficient due to limited information about its population dynamics and ecology.', 'wiki_url': 'https://en.wikipedia.org/wiki/Lesser_capybara', 'title': 'Lesser capybara'}, {'id': 1, 'summary': 'The genus _Hydrochoerus_ includes two extant species: the Common Capybara (_Hydrochoerus hydrochaeris_) and the Lesser Capybara (_Hydrochoerus isthmius_). These are the largest living rodents, found in semi-aquatic environments across South America, and are also known for their social behavior and dietary habits focused on grasses.', 'wiki_url': 'https://en.wikipedia.org/wiki/Hydrochoerus', 'title': 'Hydrochoerus'}]

# %%
clarifier_results1.output
# Out:
# 'While capybaras are currently not considered threatened and have adapted well to urban environments, potential threats to their populations can include habitat destruction, hunting, and competition for food resources with livestock and other species. Urbanization and agricultural expansion can lead to loss of natural habitats, which affects their social structures and feeding patterns. \n\nFor more detailed information, you can visit the [Capybara Wikipedia page](https://en.wikipedia.org/wiki/Capybara).'

# %%
clarifier_results1.all_messages()[2].parts[0].content
# Out:
# [{'id': 0,
#   'summary': "The capybara (Hydrochoerus hydrochaeris) is the world's largest rodent, native to South America. It thrives in savannas and dense forests near water sources and is known for its social behavior, often living in groups of 10-20 individuals that can swell to larger numbers in certain seasons. Capybaras primarily eat grasses and aquatic plants and are semi-aquatic, being excellent swimmers. They are not considered threatened and have adapted well to some urban environments, where they are sometimes kept as pets.",
#   'wiki_url': 'https://en.wikipedia.org/wiki/Capybara',
#   'title': 'Capybara'},
#  {'id': 2,
#   'summary': 'The Lesser Capybara (_Hydrochoerus isthmius_) is a large semi-aquatic rodent native to parts of South America, particularly Panama and Colombia. It is smaller than the common capybara and primarily inhabits aquatic environments, where it grazes on grasses and other plants. This species has been classified as data deficient due to limited information about its population dynamics and ecology.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Lesser_capybara',
#   'title': 'Lesser capybara'},
#  {'id': 1,
#   'summary': 'The genus _Hydrochoerus_ includes two extant species: the Common Capybara (_Hydrochoerus hydrochaeris_) and the Lesser Capybara (_Hydrochoerus isthmius_). These are the largest living rodents, found in semi-aquatic environments across South America, and are also known for their social behavior and dietary habits focused on grasses.',
#   'wiki_url': 'https://en.wikipedia.org/wiki/Hydrochoerus',
#   'title': 'Hydrochoerus'}]
